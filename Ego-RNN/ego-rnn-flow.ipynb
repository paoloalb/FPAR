# %%
import os
from __future__ import print_function, division
from flow_resnet import *
from spatial_transforms import (Compose, ToTensor, CenterCrop, Scale, Normalize, MultiScaleCornerCrop,
                                RandomHorizontalFlip)
import torch.nn as nn
from torch.autograd import Variable
from my_MakeDatasetFlow import *
import argparse
import sys
import time

DEVICE = 'cuda'  # gpu acceleration

# %%
def main_run(version, train_data_dir, outDir, stackSize, trainBatchSize, valBatchSize,
             numEpochs, lr1, stepSize, decayRate, seqLen):

    num_classes = 61

    model_folder = os.path.join("./", outDir, version)

    if os.path.exists(model_folder):
        print('Directory {} exists!'.format(model_folder))
        sys.exit()
    os.makedirs(model_folder)

    train_log_loss = open((model_folder + '/train_log_loss.txt'), 'w')
    train_log_acc = open((model_folder + '/train_log_acc.txt'), 'w')
    val_log_loss = open((model_folder + '/val_log_loss.txt'), 'w')
    val_log_acc = open((model_folder + '/val_log_acc.txt'), 'w')

    # Train val partitioning
    train_usr = ["S1", "S3", "S4"]
    val_usr = ["S2"]

    # Data loader
    normalize = Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # imagenet mean and std

    spatial_transform = Compose(
        [Scale(256), RandomHorizontalFlip(), MultiScaleCornerCrop([1, 0.875, 0.75, 0.65625], 224),
         ToTensor(), normalize])

    vid_seq_train = makeDataset(train_data_dir, train_usr, stackSize=stackSize,
                                spatial_transform=spatial_transform, seqLen=seqLen)

    train_loader = torch.utils.data.DataLoader(vid_seq_train, batch_size=trainBatchSize, 
                                               shuffle=True, sampler=None, num_workers=4, pin_memory=True)

    vid_seq_val = makeDataset(train_data_dir, val_usr, stackSize=stackSize,
                              spatial_transform=Compose([Scale(256), CenterCrop(224), ToTensor(), normalize]),
                              seqLen=seqLen)

    val_loader = torch.utils.data.DataLoader(vid_seq_val, batch_size=valBatchSize,
                                             shuffle=False, num_workers=2, pin_memory=True)
    valInstances = vid_seq_val.__len__()

    trainInstances = vid_seq_train.__len__()
    print('Number of samples in the dataset: training = {} | validation = {}'.format(trainInstances, valInstances))

    model = flow_resnet34(True, channels=2 * stackSize, num_classes=num_classes)
    model.train(True)
    train_params = list(model.parameters())

    model.cuda()

    loss_fn = nn.CrossEntropyLoss()

    optimizer_fn = torch.optim.SGD(train_params, lr=lr1, momentum=0.9, weight_decay=5e-4)

    optim_scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer_fn, milestones=stepSize, gamma=decayRate)

    train_iter = 0
    min_accuracy = 0

    for epoch in range(numEpochs):
        start_time = time.time()
        optim_scheduler.step()
        epoch_loss = 0
        numCorrTrain = 0
        trainSamples = 0
        iterPerEpoch = 0
        model.train(True)
        for i, (inputs, targets) in enumerate(train_loader):
            train_iter += 1
            iterPerEpoch += 1
            optimizer_fn.zero_grad()
            inputVariable = Variable(inputs.to(DEVICE))
            labelVariable = Variable(targets.to(DEVICE))
            trainSamples += inputs.size(0)
            output_label, _ = model(inputVariable)
            loss = loss_fn(output_label, labelVariable)
            loss.backward()
            optimizer_fn.step()
            _, predicted = torch.max(output_label.data, 1)
            numCorrTrain += (predicted == targets.to(DEVICE)).sum()  # evaluating number of correct classifications

            epoch_loss += loss.data.item()
        avg_loss = epoch_loss / iterPerEpoch
        trainAccuracy = (numCorrTrain.data.item() / trainSamples) * 100
        print('Train: Epoch = {} | Loss = {} | Accuracy = {}'.format(epoch + 1, avg_loss, trainAccuracy))
        train_log_loss.write(
            'Training loss after {} epoch = {}\n'.format(epoch + 1, avg_loss))  # log file (very good practice)
        train_log_acc.write('Training accuracy after {} epoch = {}\n'.format(epoch + 1, trainAccuracy))  # log file
        print("--- time elapsed: %.2s seconds ---" % (time.time() - start_time))
        if (epoch + 1) % 5 == 0:
            model.train(False)
            val_loss_epoch = 0
            val_iter = 0
            val_samples = 0
            numCorr = 0
            for j, (inputs, targets) in enumerate(val_loader):
                val_iter += 1
                val_samples += inputs.size(0)
                inputVariable = Variable(inputs.to(DEVICE), volatile=True)
                labelVariable = Variable(targets.to(DEVICE))
                output_label, _ = model(inputVariable)
                val_loss = loss_fn(output_label, labelVariable)
                val_loss_epoch += val_loss.data.item()
                _, predicted = torch.max(output_label.data, 1)
                numCorr += (predicted == targets.to(DEVICE)).sum()
            val_accuracy = (numCorr.data.item() / val_samples) * 100
            avg_val_loss = val_loss_epoch / val_iter
            print('Validation: Epoch = {} | Loss = {} | Accuracy = {}'.format(epoch + 1, avg_val_loss, val_accuracy))
            val_log_loss.write('Val Loss after {} epochs = {}\n'.format(epoch + 1, avg_val_loss))  # log file
            val_log_acc.write('Val Accuracy after {} epochs = {}%\n'.format(epoch + 1, val_accuracy))  # log file
            if val_accuracy > min_accuracy:
                save_path_model = (
                        model_folder + '/model_flow_state_dict.pth')  # every epoch, check if the val accuracy is improved, if so, save that model
                torch.save(model.state_dict(),
                           save_path_model)  # in that way, even if the model overfit, you will get always the best model
                min_accuracy = val_accuracy  # in this way you don't have to care too much about the number of epochs
        

    # closing files
    train_log_loss.close()
    train_log_acc.close()
    val_log_acc.close()
    val_log_loss.close()

# %%
def __main__():
    version = "flow"
    train_data_dir = "/content/"
    outDir = "results"

    stackSize = 5 #5
    trainBatchSize = 32  # 32
    valBatchSize = 32  # 32
    numEpochs = 750
    lr1 = 1e-2  # 1e-2
    stepSize = [150, 300, 500]
    decayRate = 0.5  # 0.5
    seqLen = 16  # 7

    main_run(version=version,
             train_data_dir=train_data_dir,
             outDir=outDir,
             stackSize=stackSize,
             trainBatchSize=trainBatchSize,
             valBatchSize=valBatchSize,
             numEpochs=numEpochs,
             lr1=lr1,
             stepSize=stepSize,
             decayRate=decayRate,
             seqLen=seqLen)

# %%
if __name__ == "__main__":
    __main__()
# Out:
# Number of samples in the dataset: training = 328 | validation = 116
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:123: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Train: Epoch = 1 | Loss = 4.53092657436024 | Accuracy = 2.1341463414634148
# --- time elapsed: 19 seconds ---
# Train: Epoch = 2 | Loss = 4.494368466463956 | Accuracy = 3.353658536585366
# --- time elapsed: 19 seconds ---
# Train: Epoch = 3 | Loss = 4.404225045984441 | Accuracy = 3.048780487804878
# --- time elapsed: 19 seconds ---
# Train: Epoch = 4 | Loss = 4.312865777449175 | Accuracy = 4.878048780487805
# --- time elapsed: 19 seconds ---
# Train: Epoch = 5 | Loss = 4.151527426459572 | Accuracy = 3.353658536585366
# --- time elapsed: 19 seconds ---
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 140 | Loss = 3.2588300108909607 | Accuracy = 19.82758620689655
# Train: Epoch = 141 | Loss = 3.057837204499678 | Accuracy = 21.646341463414632
# --- time elapsed: 18 seconds ---
# Train: Epoch = 142 | Loss = 3.0713489705866035 | Accuracy = 21.951219512195124
# --- time elapsed: 19 seconds ---
# Train: Epoch = 143 | Loss = 3.0566752607172187 | Accuracy = 20.73170731707317
# --- time elapsed: 18 seconds ---
# Train: Epoch = 144 | Loss = 3.1952543041922827 | Accuracy = 20.121951219512198
# --- time elapsed: 18 seconds ---
# Train: Epoch = 145 | Loss = 3.1559796550057153 | Accuracy = 17.98780487804878
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 145 | Loss = 3.336191952228546 | Accuracy = 21.551724137931032
# Train: Epoch = 146 | Loss = 3.1267057982358066 | Accuracy = 17.073170731707318
# --- time elapsed: 18 seconds ---
# Train: Epoch = 147 | Loss = 3.1100068309090356 | Accuracy = 19.20731707317073
# --- time elapsed: 18 seconds ---
# Train: Epoch = 148 | Loss = 3.1757851297205146 | Accuracy = 20.73170731707317
# --- time elapsed: 18 seconds ---
# Train: Epoch = 149 | Loss = 2.940133073113181 | Accuracy = 20.73170731707317
# --- time elapsed: 18 seconds ---
# Train: Epoch = 150 | Loss = 3.0301834886724297 | Accuracy = 23.170731707317074
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 150 | Loss = 5.830435931682587 | Accuracy = 17.24137931034483
# Train: Epoch = 151 | Loss = 3.0876319191672583 | Accuracy = 20.73170731707317
# --- time elapsed: 18 seconds ---
# Train: Epoch = 152 | Loss = 3.265424836765636 | Accuracy = 18.597560975609756
# --- time elapsed: 18 seconds ---
# Train: Epoch = 153 | Loss = 3.0751015056263316 | Accuracy = 19.51219512195122
# --- time elapsed: 18 seconds ---
# Train: Epoch = 154 | Loss = 3.133266470649026 | Accuracy = 20.73170731707317
# --- time elapsed: 18 seconds ---
# Train: Epoch = 155 | Loss = 3.0134207985617896 | Accuracy = 21.951219512195124
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 155 | Loss = 3.2644994258880615 | Accuracy = 19.82758620689655
# Train: Epoch = 156 | Loss = 3.1451157223094595 | Accuracy = 21.646341463414632
# --- time elapsed: 18 seconds ---
# Train: Epoch = 157 | Loss = 3.0520589568398218 | Accuracy = 20.426829268292682
# --- time elapsed: 18 seconds ---
# Train: Epoch = 158 | Loss = 3.057074200023304 | Accuracy = 17.98780487804878
# --- time elapsed: 18 seconds ---
# Train: Epoch = 159 | Loss = 3.151854558424516 | Accuracy = 17.378048780487802
# --- time elapsed: 18 seconds ---
# Train: Epoch = 160 | Loss = 2.996973167766224 | Accuracy = 25.0
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 160 | Loss = 2.9833150506019592 | Accuracy = 22.413793103448278
# Train: Epoch = 161 | Loss = 3.0134552825580943 | Accuracy = 16.463414634146343
# --- time elapsed: 19 seconds ---
# Train: Epoch = 162 | Loss = 2.851885210384022 | Accuracy = 24.390243902439025
# --- time elapsed: 18 seconds ---
# Train: Epoch = 163 | Loss = 2.9692553823644463 | Accuracy = 18.597560975609756
# --- time elapsed: 18 seconds ---
# Train: Epoch = 164 | Loss = 2.8559546037153765 | Accuracy = 25.0
# --- time elapsed: 18 seconds ---
# Train: Epoch = 165 | Loss = 2.9486523541537197 | Accuracy = 25.914634146341463
# --- time elapsed: 18 seconds ---
# Validation: Epoch =
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 265 | Loss = 3.1026200652122498 | Accuracy = 21.551724137931032
# Train: Epoch = 266 | Loss = 2.416547038338401 | Accuracy = 33.23170731707317
# --- time elapsed: 18 seconds ---
# Train: Epoch = 267 | Loss = 2.1677158637480303 | Accuracy = 34.45121951219512
# --- time elapsed: 18 seconds ---
# Train: Epoch = 268 | Loss = 2.402763605117798 | Accuracy = 35.0609756097561
# --- time elapsed: 18 seconds ---
# Train: Epoch = 269 | Loss = 2.324073141271418 | Accuracy = 35.0609756097561
# --- time elapsed: 18 seconds ---
# Train: Epoch = 270 | Loss = 2.2506382898850874 | Accuracy = 37.19512195121951
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 270 | Loss = 3.1893935203552246 | Accuracy = 24.137931034482758
# Train: Epoch = 271 | Loss = 2.306199984116988 | Accuracy = 37.5
# --- time elapsed: 18 seconds ---
# Train: Epoch = 272 | Loss = 2.5081028179688887 | Accuracy = 34.756097560975604
# --- time elapsed: 18 seconds ---
# Train: Epoch = 273 | Loss = 2.608635663986206 | Accuracy = 30.79268292682927
# --- time elapsed: 18 seconds ---
# Train: Epoch = 274 | Loss = 2.643608808517456 | Accuracy = 31.70731707317073
# --- time elapsed: 18 seconds ---
# Train: Epoch = 275 | Loss = 2.6309808384288442 | Accuracy = 29.268292682926827
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 275 | Loss = 3.26839143037796 | Accuracy = 22.413793103448278
# Train: Epoch = 276 | Loss = 2.5740039348602295 | Accuracy = 32.01219512195122
# --- time elapsed: 18 seconds ---
# Train: Epoch = 277 | Loss = 2.5349488908594306 | Accuracy = 34.756097560975604
# --- time elapsed: 18 seconds ---
# Train: Epoch = 278 | Loss = 2.2449468916112725 | Accuracy = 36.28048780487805
# --- time elapsed: 18 seconds ---
# Train: Epoch = 279 | Loss = 2.395232070576061 | Accuracy = 32.6219512195122
# --- time elapsed: 18 seconds ---
# Train: Epoch = 280 | Loss = 2.3006338639692827 | Accuracy = 34.45121951219512
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 280 | Loss = 3.506321966648102 | Accuracy = 17.24137931034483
# Train: Epoch = 281 | Loss = 2.4183117909864946 | Accuracy = 36.58536585365854
# --- time elapsed: 18 seconds ---
# Train: Epoch = 282 | Loss = 2.3300916715101763 | Accuracy = 34.146341463414636
# --- time elapsed: 18 seconds ---
# Train: Epoch = 283 | Loss = 2.345859863541343 | Accuracy = 35.97560975609756
# --- time elapsed: 18 seconds ---
# Train: Epoch = 284 | Loss = 2.3973032127727163 | Accuracy = 34.45121951219512
# --- time elapsed: 18 seconds ---
# Train: Epoch = 285 | Loss = 2.2664413885636763 | Accuracy = 37.5
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 285 | Loss = 3.517739415168762 | Accuracy = 18.103448275862068
# Train: Epoch = 286 | Loss = 2.310125090859153 | Accuracy = 35.670731707317074
# --- time elapsed: 18 seconds ---
# Train: Epoch = 287 | Loss = 2.461069096218456 | Accuracy = 32.31707317073171
# --- time elapsed: 18 seconds ---
# Train: Epoch = 288 | Loss = 2.3901221535422583 | Accuracy = 34.756097560975604
# --- time elapsed: 18 seconds ---
# Train: Epoch = 289 | Loss = 2.146370454268022 | Accuracy = 38.109756097560975
# --- time elapsed: 18 seconds ---
# Train: Epoch = 290 | Loss = 2.2568482268940318 | Accuracy = 40.243902439024396
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 290 | Loss = 3.1732475757598877 | Accuracy = 25.0
# Train: Epoch = 291 | Loss = 2.1386296532370825 | Accuracy = 37.5
# --- time elapsed: 18 seconds ---
# Train: Epoch = 292 | Loss = 2.26800612969832 | Accuracy = 35.670731707317074
# --- time elapsed: 18 seconds ---
# Train: Epoch = 293 | Loss = 2.0903516574339434 | Accuracy = 40.54878048780488
# --- time elapsed: 18 seconds ---
# Train: Epoch = 294 | Loss = 2.234338576143438 | Accuracy = 35.97560975609756
# --- time elapsed: 18 seconds ---
# Train: Epoch = 295 | Loss = 2.1406337239525537 | Accuracy = 39.9390243902439
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 295 | Loss = 3.5319655537605286 | Accuracy = 23.275862068965516
# Train: Epoch = 296 | Loss = 2.118726546114141 | Accuracy = 39.329268292682926
# --- time elapsed: 18 seconds ---
# Train: Epoch = 297 | Loss = 2.0953152288090098 | Accuracy = 39.9390243902439
# --- time elapsed: 18 seconds ---
# Train: Epoch = 298 | Loss = 2.1226634329015557 | Accuracy = 38.109756097560975
# --- time elapsed: 18 seconds ---
# Train: Epoch = 299 | Loss = 2.11142081564123 | Accuracy = 39.02439024390244
# --- time elapsed: 18 seconds ---
# Train: Epoch = 300 | Loss = 2.08366013656963 | Accuracy = 40.243902439024396
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 300 | Loss = 3.26589173078537 | Accuracy = 24.137931034482758
# Train: Epoch = 301 | Loss = 2.1469590447165747 | Accuracy = 40.54878048780488
# --- time elapsed: 18 seconds ---
# Train: Epoch = 302 | Loss = 2.017764850096269 | Accuracy = 42.98780487804878
# --- time elapsed: 18 seconds ---
# Train: Epoch = 303 | Loss = 1.9884059862657026 | Accuracy = 39.63414634146341
# --- time elapsed: 18 seconds ---
# Train: Epoch = 304 | Loss = 2.121751232580705 | Accuracy = 44.81707317073171
# --- time elapsed: 18 seconds ---
# Train: Epoch = 305 | Loss = 1.927277391607111 | Accuracy = 45.426829268292686
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 305 | Loss = 2.995307743549347 | Accuracy = 31.896551724137932
# Train: Epoch = 306 | Loss = 1.8949927525086836 | Accuracy = 45.73170731707317
# --- time elapsed: 18 seconds ---
# Train: Epoch = 307 | Loss = 1.9605692733417859 | Accuracy = 44.81707317073171
# --- time elapsed: 18 seconds ---
# Train: Epoch = 308 | Loss = 1.9056147662076084 | Accuracy = 47.5609756097561
# --- time elapsed: 18 seconds ---
# Train: Epoch = 309 | Loss = 1.9756757779554888 | Accuracy = 40.853658536585364
# --- time elapsed: 18 seconds ---
# Train: Epoch = 310 | Loss = 1.873679139397361 | Accuracy = 48.47560975609756
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 310 | Loss = 3.240582525730133 | Accuracy = 27.586206896551722
# Train: Epoch = 311 | Loss = 1.845715414394032 | Accuracy = 44.81707317073171
# --- time elapsed: 18 seconds ---
# Train: Epoch = 312 | Loss = 1.9424768686294556 | Accuracy = 46.646341463414636
# --- time elapsed: 18 seconds ---
# Train: Epoch = 313 | Loss = 1.8533899133855647 | Accuracy = 46.34146341463415
# --- time elapsed: 18 seconds ---
# Train: Epoch = 314 | Loss = 1.877217715436762 | Accuracy = 47.86585365853659
# --- time elapsed: 18 seconds ---
# Train: Epoch = 315 | Loss = 1.8811673576181585 | Accuracy = 47.86585365853659
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 315 | Loss = 3.2795746326446533 | Accuracy = 27.586206896551722
# Train: Epoch = 316 | Loss = 1.924409812146967 | Accuracy = 47.256097560975604
# --- time elapsed: 18 seconds ---
# Train: Epoch = 317 | Loss = 1.867776177146218 | Accuracy = 50.0
# --- time elapsed: 19 seconds ---
# Train: Epoch = 318 | Loss = 1.9146201393821023 | Accuracy = 49.08536585365854
# --- time elapsed: 19 seconds ---
# Train: Epoch = 319 | Loss = 1.8514656153592197 | Accuracy = 48.47560975609756
# --- time elapsed: 18 seconds ---
# Train: Epoch = 320 | Loss = 1.8209109414707532 | Accuracy = 46.03658536585366
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 320 | Loss = 3.168165922164917 | Accuracy = 30.17241379310345
# Train: Epoch = 321 | Loss = 1.9974536895751953 | Accuracy = 41.46341463414634
# --- time elapsed: 18 seconds ---
# Train: Epoch = 322 | Loss = 1.7782312739979138 | Accuracy = 48.170731707317074
# --- time elapsed: 18 seconds ---
# Train: Epoch = 323 | Loss = 1.8594390045512805 | Accuracy = 46.95121951219512
# --- time elapsed: 18 seconds ---
# Train: Epoch = 324 | Loss = 1.8147554397583008 | Accuracy = 50.91463414634146
# --- time elapsed: 18 seconds ---
# Train: Epoch = 325 | Loss = 1.7805050178007646 | Accuracy = 47.5609756097561
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 325 | Loss = 3.172584056854248 | Accuracy = 22.413793103448278
# Train: Epoch = 326 | Loss = 1.8692644401030107 | Accuracy = 49.08536585365854
# --- time elapsed: 18 seconds ---
# Train: Epoch = 327 | Loss = 1.8518508997830478 | Accuracy = 48.78048780487805
# --- time elapsed: 18 seconds ---
# Train: Epoch = 328 | Loss = 1.766568292271007 | Accuracy = 49.69512195121951
# --- time elapsed: 18 seconds ---
# Train: Epoch = 329 | Loss = 1.7997623465277932 | Accuracy = 49.08536585365854
# --- time elapsed: 18 seconds ---
# Train: Epoch = 330 | Loss = 1.7983860861171375 | Accuracy = 48.47560975609756
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 330 | Loss = 2.9260388016700745 | Accuracy = 30.17241379310345
# Train: Epoch = 331 | Loss = 1.7325952920046719 | Accuracy = 48.47560975609756
# --- time elapsed: 18 seconds ---
# Train: Epoch = 332 | Loss = 1.8750010078603572 | Accuracy = 51.52439024390244
# --- time elapsed: 18 seconds ---
# Train: Epoch = 333 | Loss = 1.908346783031117 | Accuracy = 46.03658536585366
# --- time elapsed: 18 seconds ---
# Train: Epoch = 334 | Loss = 1.8022956523028286 | Accuracy = 47.256097560975604
# --- time elapsed: 18 seconds ---
# Train: Epoch = 335 | Loss = 1.7283172065561467 | Accuracy = 51.52439024390244
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 335 | Loss = 3.2289074659347534 | Accuracy = 27.586206896551722
# Train: Epoch = 336 | Loss = 1.799392277544195 | Accuracy = 51.829268292682926
# --- time elapsed: 18 seconds ---
# Train: Epoch = 337 | Loss = 1.7289475310932507 | Accuracy = 51.21951219512195
# --- time elapsed: 18 seconds ---
# Train: Epoch = 338 | Loss = 1.7318774678490378 | Accuracy = 53.65853658536586
# --- time elapsed: 18 seconds ---
# Train: Epoch = 339 | Loss = 1.9103298512372104 | Accuracy = 46.03658536585366
# --- time elapsed: 18 seconds ---
# Train: Epoch = 340 | Loss = 1.7416047616438433 | Accuracy = 51.829268292682926
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 340 | Loss = 3.1379626989364624 | Accuracy = 25.862068965517242
# Train: Epoch = 341 | Loss = 1.6737899780273438 | Accuracy = 49.08536585365854
# --- time elapsed: 18 seconds ---
# Train: Epoch = 342 | Loss = 1.6716699600219727 | Accuracy = 50.0
# --- time elapsed: 18 seconds ---
# Train: Epoch = 343 | Loss = 1.6401140798221936 | Accuracy = 51.21951219512195
# --- time elapsed: 18 seconds ---
# Train: Epoch = 344 | Loss = 1.7746557539159602 | Accuracy = 50.609756097560975
# --- time elapsed: 18 seconds ---
# Train: Epoch = 345 | Loss = 1.7004994695836848 | Accuracy = 53.65853658536586
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 345 | Loss = 3.27362459897995 | Accuracy = 27.586206896551722
# Train: Epoch = 346 | Loss = 1.8483527465300127 | Accuracy = 48.170731707317074
# --- time elapsed: 18 seconds ---
# Train: Epoch = 347 | Loss = 1.7710306319323452 | Accuracy = 50.609756097560975
# --- time elapsed: 18 seconds ---
# Train: Epoch = 348 | Loss = 1.7927318594672463 | Accuracy = 47.256097560975604
# --- time elapsed: 18 seconds ---
# Train: Epoch = 349 | Loss = 1.9325527277859775 | Accuracy = 48.78048780487805
# --- time elapsed: 18 seconds ---
# Train: Epoch = 350 | Loss = 1.728671052239158 | Accuracy = 51.829268292682926
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 350 | Loss = 2.6959980130195618 | Accuracy = 35.3448275862069
# Train: Epoch = 351 | Loss = 1.8239816969091243 | Accuracy = 52.4390243902439
# --- time elapsed: 18 seconds ---
# Train: Epoch = 352 | Loss = 1.7845763618295842 | Accuracy = 50.609756097560975
# --- time elapsed: 18 seconds ---
# Train: Epoch = 353 | Loss = 1.850028937513178 | Accuracy = 49.390243902439025
# --- time elapsed: 18 seconds ---
# Train: Epoch = 354 | Loss = 1.617559183727611 | Accuracy = 54.57317073170732
# --- time elapsed: 18 seconds ---
# Train: Epoch = 355 | Loss = 1.647255778312683 | Accuracy = 53.65853658536586
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 355 | Loss = 2.8126078248023987 | Accuracy = 36.206896551724135
# Train: Epoch = 356 | Loss = 1.7440182729200884 | Accuracy = 49.390243902439025
# --- time elapsed: 18 seconds ---
# Train: Epoch = 357 | Loss = 1.7835584120316939 | Accuracy = 51.829268292682926
# --- time elapsed: 18 seconds ---
# Train: Epoch = 358 | Loss = 1.6816244667226619 | Accuracy = 51.829268292682926
# --- time elapsed: 18 seconds ---
# Train: Epoch = 359 | Loss = 1.6252140673724087 | Accuracy = 51.52439024390244
# --- time elapsed: 18 seconds ---
# Train: Epoch = 360 | Loss = 1.7267537767236882 | Accuracy = 51.829268292682926
# --- time elapsed: 18 seconds ---
# Validation: Epoch =
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 635 | Loss = 3.391454517841339 | Accuracy = 34.48275862068966
# Train: Epoch = 636 | Loss = 0.7851867621595209 | Accuracy = 76.82926829268293
# --- time elapsed: 19 seconds ---
# Train: Epoch = 637 | Loss = 0.785111278295517 | Accuracy = 79.26829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 638 | Loss = 0.7340503307906064 | Accuracy = 79.57317073170732
# --- time elapsed: 18 seconds ---
# Train: Epoch = 639 | Loss = 0.8117394338954579 | Accuracy = 78.35365853658537
# --- time elapsed: 18 seconds ---
# Train: Epoch = 640 | Loss = 0.7619415792551908 | Accuracy = 78.35365853658537
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 640 | Loss = 3.3550907969474792 | Accuracy = 38.793103448275865
# Train: Epoch = 641 | Loss = 0.7648972435431047 | Accuracy = 78.96341463414635
# --- time elapsed: 19 seconds ---
# Train: Epoch = 642 | Loss = 0.6998720819299872 | Accuracy = 78.65853658536585
# --- time elapsed: 18 seconds ---
# Train: Epoch = 643 | Loss = 0.8179980570619757 | Accuracy = 76.21951219512195
# --- time elapsed: 18 seconds ---
# Train: Epoch = 644 | Loss = 0.7017846459692175 | Accuracy = 79.57317073170732
# --- time elapsed: 18 seconds ---
# Train: Epoch = 645 | Loss = 0.898656509139321 | Accuracy = 76.52439024390245
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 645 | Loss = 3.7218955159187317 | Accuracy = 31.03448275862069
# Train: Epoch = 646 | Loss = 0.7625512751665983 | Accuracy = 81.40243902439023
# --- time elapsed: 18 seconds ---
# Train: Epoch = 647 | Loss = 0.9400475892153654 | Accuracy = 74.6951219512195
# --- time elapsed: 18 seconds ---
# Train: Epoch = 648 | Loss = 0.7886194126172499 | Accuracy = 76.82926829268293
# --- time elapsed: 18 seconds ---
# Train: Epoch = 649 | Loss = 0.9075972817160867 | Accuracy = 71.03658536585365
# --- time elapsed: 18 seconds ---
# Train: Epoch = 650 | Loss = 0.7731482982635498 | Accuracy = 79.57317073170732
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 650 | Loss = 3.4766408801078796 | Accuracy = 33.62068965517241
# Train: Epoch = 651 | Loss = 0.8177020062099803 | Accuracy = 75.91463414634147
# --- time elapsed: 18 seconds ---
# Train: Epoch = 652 | Loss = 0.9943973530422557 | Accuracy = 73.17073170731707
# --- time elapsed: 19 seconds ---
# Train: Epoch = 653 | Loss = 0.9783363233913075 | Accuracy = 71.34146341463415
# --- time elapsed: 18 seconds ---
# Train: Epoch = 654 | Loss = 0.7626211453567852 | Accuracy = 78.65853658536585
# --- time elapsed: 18 seconds ---
# Train: Epoch = 655 | Loss = 0.8359692042524164 | Accuracy = 76.52439024390245
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 655 | Loss = 3.601974666118622 | Accuracy = 30.17241379310345
# Train: Epoch = 656 | Loss = 0.7706135403026234 | Accuracy = 77.4390243902439
# --- time elapsed: 18 seconds ---
# Train: Epoch = 657 | Loss = 0.8080300932580774 | Accuracy = 75.91463414634147
# --- time elapsed: 18 seconds ---
# Train: Epoch = 658 | Loss = 0.7732528881593184 | Accuracy = 77.4390243902439
# --- time elapsed: 18 seconds ---
# Train: Epoch = 659 | Loss = 0.8510265187783674 | Accuracy = 77.13414634146342
# --- time elapsed: 18 seconds ---
# Train: Epoch = 660 | Loss = 0.7043470279736952 | Accuracy = 78.04878048780488
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 660 | Loss = 3.6082159280776978 | Accuracy = 37.93103448275862
# Train: Epoch = 661 | Loss = 0.8397372527555986 | Accuracy = 75.3048780487805
# --- time elapsed: 19 seconds ---
# Train: Epoch = 662 | Loss = 0.7742635120045055 | Accuracy = 78.65853658536585
# --- time elapsed: 18 seconds ---
# Train: Epoch = 663 | Loss = 0.8371702324260365 | Accuracy = 76.82926829268293
# --- time elapsed: 18 seconds ---
# Train: Epoch = 664 | Loss = 0.8223574432459745 | Accuracy = 76.52439024390245
# --- time elapsed: 19 seconds ---
# Train: Epoch = 665 | Loss = 0.7051281224597584 | Accuracy = 76.82926829268293
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 665 | Loss = 3.6485654711723328 | Accuracy = 31.896551724137932
# Train: Epoch = 666 | Loss = 0.7922979647463019 | Accuracy = 79.26829268292683
# --- time elapsed: 18 seconds ---
# Train: Epoch = 667 | Loss = 0.7960201122544028 | Accuracy = 75.60975609756098
# --- time elapsed: 19 seconds ---
# Train: Epoch = 668 | Loss = 0.8119046850637957 | Accuracy = 77.4390243902439
# --- time elapsed: 19 seconds ---
# Train: Epoch = 669 | Loss = 0.6798753033984791 | Accuracy = 78.65853658536585
# --- time elapsed: 18 seconds ---
# Train: Epoch = 670 | Loss = 0.8375448259440336 | Accuracy = 72.2560975609756
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 670 | Loss = 3.6488208770751953 | Accuracy = 31.03448275862069
# Train: Epoch = 671 | Loss = 0.811609766700051 | Accuracy = 75.91463414634147
# --- time elapsed: 19 seconds ---
# Train: Epoch = 672 | Loss = 0.690755928104574 | Accuracy = 80.1829268292683
# --- time elapsed: 18 seconds ---
# Train: Epoch = 673 | Loss = 0.6227284561504017 | Accuracy = 82.3170731707317
# --- time elapsed: 19 seconds ---
# Train: Epoch = 674 | Loss = 0.7029673037203875 | Accuracy = 81.40243902439023
# --- time elapsed: 18 seconds ---
# Train: Epoch = 675 | Loss = 0.7259073528376493 | Accuracy = 79.26829268292683
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 675 | Loss = 3.6045369505882263 | Accuracy = 33.62068965517241
# Train: Epoch = 676 | Loss = 0.754260930148038 | Accuracy = 78.04878048780488
# --- time elapsed: 19 seconds ---
# Train: Epoch = 677 | Loss = 0.7476620105179873 | Accuracy = 77.7439024390244
# --- time elapsed: 19 seconds ---
# Train: Epoch = 678 | Loss = 0.7594251036643982 | Accuracy = 78.04878048780488
# --- time elapsed: 18 seconds ---
# Train: Epoch = 679 | Loss = 0.7180161286484111 | Accuracy = 78.65853658536585
# --- time elapsed: 18 seconds ---
# Train: Epoch = 680 | Loss = 0.7330715981396762 | Accuracy = 78.96341463414635
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 680 | Loss = 3.627659857273102 | Accuracy = 33.62068965517241
# Train: Epoch = 681 | Loss = 0.7784228487448259 | Accuracy = 77.7439024390244
# --- time elapsed: 19 seconds ---
# Train: Epoch = 682 | Loss = 0.7714109908450734 | Accuracy = 77.7439024390244
# --- time elapsed: 19 seconds ---
# Train: Epoch = 683 | Loss = 0.8317215984517877 | Accuracy = 77.13414634146342
# --- time elapsed: 19 seconds ---
# Train: Epoch = 684 | Loss = 0.8308997560631145 | Accuracy = 78.35365853658537
# --- time elapsed: 18 seconds ---
# Train: Epoch = 685 | Loss = 0.826983936808326 | Accuracy = 76.52439024390245
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 685 | Loss = 3.519249677658081 | Accuracy = 35.3448275862069
# Train: Epoch = 686 | Loss = 0.7600939571857452 | Accuracy = 78.35365853658537
# --- time elapsed: 19 seconds ---
# Train: Epoch = 687 | Loss = 0.7100304338065061 | Accuracy = 79.26829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 688 | Loss = 0.9200114391066812 | Accuracy = 74.39024390243902
# --- time elapsed: 19 seconds ---
# Train: Epoch = 689 | Loss = 0.7931564368984916 | Accuracy = 78.96341463414635
# --- time elapsed: 19 seconds ---
# Train: Epoch = 690 | Loss = 0.8221611055460843 | Accuracy = 79.26829268292683
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 690 | Loss = 4.096368730068207 | Accuracy = 31.896551724137932
# Train: Epoch = 691 | Loss = 0.8653835545886647 | Accuracy = 75.60975609756098
# --- time elapsed: 18 seconds ---
# Train: Epoch = 692 | Loss = 0.739624408158389 | Accuracy = 79.8780487804878
# --- time elapsed: 18 seconds ---
# Train: Epoch = 693 | Loss = 0.7003979276527058 | Accuracy = 79.26829268292683
# --- time elapsed: 18 seconds ---
# Train: Epoch = 694 | Loss = 0.8464928540316495 | Accuracy = 75.3048780487805
# --- time elapsed: 18 seconds ---
# Train: Epoch = 695 | Loss = 0.706855448809537 | Accuracy = 77.7439024390244
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 695 | Loss = 3.605374753475189 | Accuracy = 31.896551724137932
# Train: Epoch = 696 | Loss = 0.7901878411119635 | Accuracy = 79.57317073170732
# --- time elapsed: 18 seconds ---
# Train: Epoch = 697 | Loss = 0.8423064188523726 | Accuracy = 80.1829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 698 | Loss = 0.8509343808347528 | Accuracy = 76.21951219512195
# --- time elapsed: 19 seconds ---
# Train: Epoch = 699 | Loss = 0.760296187617562 | Accuracy = 77.7439024390244
# --- time elapsed: 19 seconds ---
# Train: Epoch = 700 | Loss = 0.7625165148214861 | Accuracy = 81.09756097560977
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 700 | Loss = 3.918413281440735 | Accuracy = 34.48275862068966
# Train: Epoch = 701 | Loss = 0.7621740861372515 | Accuracy = 78.96341463414635
# --- time elapsed: 19 seconds ---
# Train: Epoch = 702 | Loss = 0.7239480723034252 | Accuracy = 78.35365853658537
# --- time elapsed: 19 seconds ---
# Train: Epoch = 703 | Loss = 0.7139641696756537 | Accuracy = 78.04878048780488
# --- time elapsed: 19 seconds ---
# Train: Epoch = 704 | Loss = 0.8536849861795252 | Accuracy = 74.6951219512195
# --- time elapsed: 18 seconds ---
# Train: Epoch = 705 | Loss = 0.7733178463849154 | Accuracy = 79.57317073170732
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 705 | Loss = 3.6117659211158752 | Accuracy = 33.62068965517241
# Train: Epoch = 706 | Loss = 0.7381116368553855 | Accuracy = 78.35365853658537
# --- time elapsed: 19 seconds ---
# Train: Epoch = 707 | Loss = 0.6645624745975841 | Accuracy = 79.8780487804878
# --- time elapsed: 18 seconds ---
# Train: Epoch = 708 | Loss = 0.7497681325132196 | Accuracy = 77.7439024390244
# --- time elapsed: 19 seconds ---
# Train: Epoch = 709 | Loss = 0.7818854559551586 | Accuracy = 79.26829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 710 | Loss = 0.6340296972881664 | Accuracy = 83.53658536585365
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 710 | Loss = 3.7710387110710144 | Accuracy = 33.62068965517241
# Train: Epoch = 711 | Loss = 0.6349555037238381 | Accuracy = 82.01219512195121
# --- time elapsed: 18 seconds ---
# Train: Epoch = 712 | Loss = 0.7089918066154827 | Accuracy = 81.09756097560977
# --- time elapsed: 19 seconds ---
# Train: Epoch = 713 | Loss = 0.6956230456178839 | Accuracy = 80.48780487804879
# --- time elapsed: 19 seconds ---
# Train: Epoch = 714 | Loss = 0.7437726638533853 | Accuracy = 78.65853658536585
# --- time elapsed: 19 seconds ---
# Train: Epoch = 715 | Loss = 0.849820538000627 | Accuracy = 75.60975609756098
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 715 | Loss = 3.6140578389167786 | Accuracy = 37.06896551724138
# Train: Epoch = 716 | Loss = 0.7880783812566237 | Accuracy = 78.65853658536585
# --- time elapsed: 19 seconds ---
# Train: Epoch = 717 | Loss = 0.7211912274360657 | Accuracy = 79.26829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 718 | Loss = 0.6742587306282737 | Accuracy = 79.57317073170732
# --- time elapsed: 19 seconds ---
# Train: Epoch = 719 | Loss = 0.7341986921700564 | Accuracy = 78.96341463414635
# --- time elapsed: 19 seconds ---
# Train: Epoch = 720 | Loss = 0.6414842199195515 | Accuracy = 84.45121951219512
# --- time elapsed: 18 seconds ---
# Validation: Epoch = 720 | Loss = 3.830797255039215 | Accuracy = 30.17241379310345
# Train: Epoch = 721 | Loss = 0.7645492038943551 | Accuracy = 79.26829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 722 | Loss = 0.7806425121697512 | Accuracy = 80.1829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 723 | Loss = 0.6723848283290863 | Accuracy = 83.84146341463415
# --- time elapsed: 19 seconds ---
# Train: Epoch = 724 | Loss = 0.7767070884054358 | Accuracy = 78.65853658536585
# --- time elapsed: 19 seconds ---
# Train: Epoch = 725 | Loss = 0.7527167797088623 | Accuracy = 77.13414634146342
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 725 | Loss = 3.481084108352661 | Accuracy = 37.93103448275862
# Train: Epoch = 726 | Loss = 0.6528505818410353 | Accuracy = 83.84146341463415
# --- time elapsed: 19 seconds ---
# Train: Epoch = 727 | Loss = 0.6912756806070154 | Accuracy = 82.3170731707317
# --- time elapsed: 19 seconds ---
# Train: Epoch = 728 | Loss = 0.65228886495937 | Accuracy = 81.70731707317073
# --- time elapsed: 19 seconds ---
# Train: Epoch = 729 | Loss = 0.7025503841313449 | Accuracy = 80.1829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 730 | Loss = 0.7105157023126428 | Accuracy = 80.1829268292683
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 730 | Loss = 3.611011028289795 | Accuracy = 32.758620689655174
# Train: Epoch = 731 | Loss = 0.7526950565251437 | Accuracy = 82.6219512195122
# --- time elapsed: 19 seconds ---
# Train: Epoch = 732 | Loss = 0.687195515090769 | Accuracy = 80.1829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 733 | Loss = 0.7684899893673983 | Accuracy = 76.82926829268293
# --- time elapsed: 19 seconds ---
# Train: Epoch = 734 | Loss = 0.7644616744735024 | Accuracy = 75.91463414634147
# --- time elapsed: 19 seconds ---
# Train: Epoch = 735 | Loss = 0.7239330383864316 | Accuracy = 81.09756097560977
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 735 | Loss = 3.8137413263320923 | Accuracy = 31.896551724137932
# Train: Epoch = 736 | Loss = 0.7320986010811545 | Accuracy = 77.4390243902439
# --- time elapsed: 19 seconds ---
# Train: Epoch = 737 | Loss = 0.7495566498149525 | Accuracy = 78.96341463414635
# --- time elapsed: 19 seconds ---
# Train: Epoch = 738 | Loss = 0.7203906043009325 | Accuracy = 78.35365853658537
# --- time elapsed: 19 seconds ---
# Train: Epoch = 739 | Loss = 0.650245726108551 | Accuracy = 81.09756097560977
# --- time elapsed: 19 seconds ---
# Train: Epoch = 740 | Loss = 0.7962959788062356 | Accuracy = 78.65853658536585
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 740 | Loss = 3.839542508125305 | Accuracy = 30.17241379310345
# Train: Epoch = 741 | Loss = 0.5479024377736178 | Accuracy = 83.23170731707317
# --- time elapsed: 18 seconds ---
# Train: Epoch = 742 | Loss = 0.7274433482776989 | Accuracy = 80.48780487804879
# --- time elapsed: 19 seconds ---
# Train: Epoch = 743 | Loss = 0.7454269013621591 | Accuracy = 80.1829268292683
# --- time elapsed: 19 seconds ---
# Train: Epoch = 744 | Loss = 0.7681494707410986 | Accuracy = 78.04878048780488
# --- time elapsed: 19 seconds ---
# Train: Epoch = 745 | Loss = 0.6690511784770272 | Accuracy = 78.35365853658537
# --- time elapsed: 19 seconds ---
# Validation: Epoch = 745 | Loss = 3.6355255842208862 | Accuracy = 31.896551724137932
# Train: Epoch = 746 | Loss = 0.6154733544046228 | Accuracy = 80.79268292682927
# --- time elapsed: 19 seconds ---
# Train: Epoch = 747 | Loss = 0.7749549638141285 | Accuracy = 78.35365853658537
# --- time elapsed: 19 seconds ---
# Train: Epoch = 748 | Loss = 0.6670079691843553 | Accuracy = 81.40243902439023
# --- time elapsed: 19 seconds ---
# Train: Epoch = 749 | Loss = 0.7131927636536685 | Accuracy = 80.48780487804879
# --- time elapsed: 19 seconds ---
# Train: Epoch = 750 | Loss = 0.525697414170612 | Accuracy = 86.28048780487805
# --- time elapsed: 20 seconds ---
# Validation: Epoch = 750 | Loss = 3.628708600997925 | Accuracy = 32.758620689655174
